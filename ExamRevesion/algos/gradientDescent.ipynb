# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats,info
import numpy as np

# %%
info(stats)
# Out:
# .. _statsrefmanual:
#
# ...
# Statistical functions (:mod:`scipy.stats`)
# ...
#
# .. currentmodule:: scipy.stats
#
# This module contains a large number of probability distributions,
# summary and frequency statistics, correlation functions and statistical
# tests, masked statistics, kernel density estimation, quasi-Monte Carlo
# functionality, and more.
#
# Statistics is a very large area, and there are topics that are out of scope
# for SciPy and are covered by other packages. Some of the most important ones
# are:
#
# - `statsmodels <https://www.statsmodels.org/stable/index.html>`__:
#   regression, linear models, time series analysis, extensions to topics
#   also covered by ``scipy.stats``.
# - `Pandas <https://pandas.pydata.org/>`__: tabular data, time series
#   functionality, interfaces to other statistical languages.
# - `PyMC <https://docs.pymc.io/>`__: Bayesian statistical
#   modeling, probabilistic machine learning.
# ...

# %%
df = pd.read_csv('../resources/univariate_linear_regression_dataset.csv')
df.columns = ['x','y']
X = df.x
X = X.values
Y = df.y

# %%
axes = plt.axes()
axes.grid()
plt.scatter(X,Y)
plt.show()

# %%
SL = stats.linregress(X,Y)
slope = SL.slope
intercept = SL.intercept
rvalue = SL.rvalue
def predict(X):
    return slope*X + intercept

plt.plot(X,predict(X),c='r')
plt.scatter(X,Y)
plt.show()
SL
# Out:
# LinregressResult(slope=1.2135472539083587, intercept=-4.211504005424093, rvalue=0.8721572919685905, pvalue=6.110460481642768e-31, stderr=0.07021131328791101, intercept_stderr=0.6352591889336102)

# %% [markdown]
# ## Now let's build our own function to make the gradient descent

# %%
def model(X,Theta):
        return X.dot(Teta)

# %%
def err(X,y,Theta):
    m = len(X)
    return np.sum((model(X,Teta)-y)**2)/(2*m)

# %%
def gradient(X,y,Theta):
    m = len(X)
    return X.T.dot(model(X,Theta)-y)

# %%
def gradientDescent(X,Theta,y,alpha,n_iterations):
    for i in range(n_iterations):
        Theta-= alpha*gradient(X,y,Theta)
    return Theta

# %%
plt.scatter(X,Y)
X.shape = (len(X),1)
newX = np.hstack((X,np.ones(X.shape)))
# theta = gradientDescent(newX,np.random.randn(2, 1),Y,0.01,100)
# plt.plot(model(newX,theta),Y)
newX.shape
# Out:
# (96, 2)

# %%
df.x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/mldl/lib/python3.9/site-packages/IPython/core/formatters.py:707, in PlainTextFormatter.__call__(self, obj)
#     700 stream = StringIO()
#     701 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     702     self.max_width, self.newline,
#     703     max_seq_length=self.max_seq_length,
#     704     singleton_pprinters=self.singleton_printers,
#     705     type_pprinters=self.type_printers,
#     706     deferred_pprinters=self.deferred_printers)
# --> 707 printer.pretty(obj)
#     708 printer.flush()
#     709 return stream.getvalue()
#
# File ~/anaconda3/envs/mldl/lib/python3.9/site-packages/IPython/lib/pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
# ...
