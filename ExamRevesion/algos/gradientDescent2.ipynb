# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../resources/univariate_linear_regression_dataset.csv')
data.columns = ["X","y"]
x = data.X.values
X = np.vstack((x,np.ones(x.shape))).T
y = data.y.values
y.shape = (len(y),1)

# %%
plt.grid()
plt.scatter(x,y)
plt.show()

# %%
# theta shoud be represented by a columns
def model(X,theta):
    return X.dot(theta)

# %%
theta = np.random.randn(2,1)
predicted = model(X,theta)
plt.grid()
plt.scatter(x,y)
plt.plot(x,predicted,c='orange')
plt.show()

# %%
def loss(predicted,y):
    m = len(y)
    return np.sum((predicted-y)**2)/(2*m)
loss(predicted,y)
# Out:
# 257.53129641444946

# %%
def gradient(X,y,theta):
    m = len(y)
    return (1/m)*X.T.dot(X.dot(theta)-y)
gradient(X,y,theta)
# Out:
# array([[-203.66744914],
#        [ -19.8417829 ]])

# %%
def gradientDescent(X,y,theta,learning_rate = 0.01,n_iterations = 1000):
    for i in range(n_iterations):
        theta -= learning_rate*gradient(X,y,theta)
    return theta
newTheta = gradientDescent(X,y,theta)
newPrediction = model(X,newTheta)
print('mean square error = ',loss(newPrediction,y))
plt.grid()
plt.scatter(x,y)
plt.plot(x,newPrediction,c = 'red')
plt.show()
# Out:
# mean square error =  3.459581903158004

# %%
newY = y**2
print('shape = ',x.shape)
newTheta2 = gradientDescent(X,newY,theta)
newPrediction = model(X,newTheta2)
plt.grid()
plt.scatter(x,newY,c = 'red')
plt.plot(x,newPrediction,c='blue')
plt.show()
newTheta2
# Out:
# shape =  (96,)
# array([[  25.6980307 ],
#        [-148.64954115]])
